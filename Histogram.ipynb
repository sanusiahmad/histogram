# %% [markdown]
# <a href="https://colab.research.google.com/github/sanusiahmad/histogram/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.pylab import imshow
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from IPython.display import Image
Image(filename='sanusi.jpeg')

# %%
im = cv2.imread('sanusi.jpeg')

vals = im.mean(axis=2).flatten()

counts, bins = np.histogram(vals, range(257))

plt.bar(bins[:-1] - 0.5, counts, width=1, edgecolor='none')
plt.xlim([-0.5, 255.5])
plt.show()

# %% [markdown]
# dapat di simpulkan bahwa foto tersebut termasuk kepada citra terang (over exposed)
